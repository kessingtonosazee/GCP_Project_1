# %% [markdown]
# <a href="https://colab.research.google.com/github/kessingtonosazee/GCP_Project_1/blob/master/data_science_challenge_phase_one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Unzip and extract into a folder named 'bbc_nlp_project'
# !unzip -q /content/bbc_nlp_project.zip -d /content/bbc_nlp_project

# %%
# list files and sub-directories
# !ls -l /content/bbc_nlp_project
# Out:
# total 20
# drwxr-xr-x 3 root root 4096 Jul  7 22:50 data
# drwxr-xr-x 2 root root 4096 Jul  8 01:11 output
# drwxr-xr-x 3 root root 4096 Jul  8 01:31 python_script
# -rw-r--r-- 1 root root  657 Jul  6 09:21 README.md
# -rw-r--r-- 1 root root   53 Jul  6 09:21 requirements.txt

# %%
# Install all required Python libraries listed in requirements.txt
# This includes libraries like pandas, scikit-learn (sklearn), spaCy, nltk, etc.
# Adjust the path to the correct file location

# !pip install -r /content/bbc_nlp_project/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.0/153.0 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 64.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 33.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 42.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# Download the small English model for spaCy (used for Named Entity Recognition and more)
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 39.2 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# Parse articles into a DataFrame
# !python bbc_nlp_project/python_script/001_data_preprocessing.py
# Out:
# Sample data:
#                                                 text  category
# 0  Tate & Lyle boss bags top award  Tate & Lyle's...  business
# 1  Halo 2 sells five million copies  Microsoft is...      tech
# 2  MSPs hear renewed climate warning  Climate cha...  politics
# 3  Pavey focuses on indoor success  Jo Pavey will...     sport
# 4  Tories reject rethink on axed MP  Sacked MP Ho...  politics
#
#  BBC dataset saved to: /content/bbc_nlp_project/data/bbc_news.csv

# %%
# Multi-Category Subtopic Modeling
# !python bbc_nlp_project/python_script/002_topic_modeling_subcategories.py
# Out:
# 2025-07-09 00:30:44.203780: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752021044.517303    2529 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752021044.605803    2529 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-09 00:30:45.268742: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# ...

# %%
import pandas as pd

# Adjust the path based on your project structure
file_path = '/content/bbc_nlp_project/output/bbc_news_with_subcategories.csv'

# Load the CSV into a DataFrame
df = pd.read_csv(file_path)

# Show the first few rows
df.tail(5)
# Out:
#                                                    text       category  \
# 2220  Singer Sizzla jailed for swearing  Reggae star...  entertainment
# 2221  Potter director signs Warner deal  Harry Potte...  entertainment
# 2222  Gervais writing Simpsons episode  The Office's...  entertainment
# 2223  Jamelia's return to the top  R&B star Jamelia ...  entertainment
# 2224  Oscars steer clear of controversy  The Oscars ...  entertainment
#
#       sub_topic sub_category
# 2220          1        music
# 2221          0       cinema
# 2222          2   television
# 2223          1        music
# 2224          0       cinema

# %%
# Named entity extraction
# !python bbc_nlp_project/python_script/003_named_entity_extraction.py
# Out:
#  Loading spaCy model...
#  Processing articles for media personalities...
#  Extraction complete. Results saved to: /content/bbc_nlp_project/output/bbc_media_personalities_detailed.csv

# %%
import pandas as pd

# Adjust the path based on your project structure
file_path = '/content/bbc_nlp_project/output/bbc_media_personalities_detailed.csv'

# Load the CSV into a DataFrame
df = pd.read_csv(file_path)

# Show the first few rows
df.tail(20)
# Out:
#       article_id       category          person                 role  \
# 5664        2211           tech  Mikko Hypponen             Director
# 5665        2211           tech     Network Box             Director
# 5666        2213  entertainment    Harry Potter             Director
# 5667        2213  entertainment  Alfonso Cuaron             Director
# 5668        2213  entertainment         Alfonso    Composer/Producer
# 5669        2213  entertainment    Harry Potter    Composer/Producer
# 5670        2213  entertainment    Jeff Robinov    Composer/Producer
# 5671        2215           tech          Millan           Politician
# 5672        2215           tech       Tote King           Politician
# 5673        2215           tech   Manuel Millan           Politician
# 5674        2215           tech       Tote King           Politician
# 5675        2216  entertainment         Gervais        Actor/Actress
# 5676        2216  entertainment           David        Actor/Actress
# ...

# %%
# april_event_summarization
# !python bbc_nlp_project/python_script/004_april_event_summarization.py
# Out:
#  Loading spaCy model...
#  Extracting April event mentions...
#  April event summaries saved to: /content/bbc_nlp_project/output/bbc_april_event_summaries.csv

# %%
import pandas as pd

# Adjust the path based on your project structure
file_path = '/content/bbc_nlp_project/output/bbc_april_event_summaries.csv'

# Load the CSV into a DataFrame
df = pd.read_csv(file_path)

# Show the first few rows
df.head(10)
# Out:
#    article_id       category  \
# 0          78       politics
# 1          81  entertainment
# 2          93       business
# 3         155       business
# 4         207       business
# 5         304       politics
# 6         396       business
# 7         411  entertainment
# 8         425       business
# 9         572       business
#
#                                april_event_sentences  \
# 0  Last April's report by the Electoral Commissio...
# 1  Shooting on the sequel is expected to begin in...
# 2  Kirin, the fourth big name, is launching its o...
# 3  The airline, the brainchild of Mr Mallya, expe...
# 4  The company also unveiled plans to cut the who...
# 5  During the interview Mr Kennedy revealed that ...
# 6  The firm reported worldwide futures orders for...
# 7  Tickets for the June event are expected to go ...
# 8  "Two million children will die needlessly betw...
# 9  Parents will need to decide which financial in...
#
# ...
