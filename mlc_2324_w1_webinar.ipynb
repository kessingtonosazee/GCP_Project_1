# %% [markdown]
# <a href="https://colab.research.google.com/github/kessingtonosazee/GCP_Project_1/blob/master/mlc_2324_w1_webinar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Key Points Week 1
#
# * Jupyter (and the like) as an interactive environment for data science and machine learning.
#
# * The mindset of notebooks:
#     - a collection of cells; typically, text (Markdown) and code cells.
#     - one would normally structure a notebook that is run in a top-down fashion.
#     - the user needs to ensure that cells are run in the order that reflects dependencies among cells.
#     - A Jupyter (or Colab) session has a state; it dies with it once you close your notebook. So, when opening a notebook, you would need to run cells for re-creating variables, loading datasets, among others.
#
# * Python as the core language for doing machine learning and data science tasks. We need to get used to some basic syntax and key constructs.
#
# * Some basic data manipulation with `pandas`; essential for any machine learning project (before getting to more sophisticated machine learning).

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('https://raw.githubusercontent.com/gerberl/6G7V0015-2324/main/datasets/diabetes.csv')

# %%
diabetes.sample()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 336            0      117              0              0        0  33.8
#
#      DiabetesPedigreeFunction  Age  Outcome
# 336                     0.932   44        0

# %%
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes[ ['BloodPressure', 'Pregnancies']  ]
# Out:
#      BloodPressure  Pregnancies
# 0               72            6
# 1               66            1
# 2               64            8
# 3               66            1
# 4               40            0
# ..             ...          ...
# 763             76           10
# 764             70            2
# 765             72            5
# 766             60            1
# 767             70            1
#
# [768 rows x 2 columns]

# %%
diabetes[ ['BloodPressure', 'Pregnancies'] ].sample(5, random_state=0)
# Out:
#      BloodPressure  Pregnancies
# 661             76            1
# 122             74            2
# 113             62            4
# 14              72            5
# 529             65            0

# %%
bpprgn = diabetes[ ['BloodPressure', 'Pregnancies'] ]
bpprgn.sample(5)
# Out:
#      BloodPressure  Pregnancies
# 549            110            4
# 679             58            2
# 121             64            6
# 693             68            7
# 373             58            2

# %%
diabetes.loc[ 549:559, ['Glucose', 'Insulin'] ]
# Out:
#      Glucose  Insulin
# 549      189        0
# 550      116        0
# 551       84      106
# 552      114        0
# 553       88       44
# 554       84      115
# 555      124      215
# 556       97        0
# 557      110        0
# 558      103        0
# 559       85        0

# %%
diabetes['Glucose']>120
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 763    False
# 764     True
# 765     True
# 766     True
# 767    False
# Name: Glucose, Length: 768, dtype: bool

# %%
len(diabetes[ diabetes['Glucose']>190 ])
# Out:
# 17

# %%
len(diabetes)
# Out:
# 768

# %%
diabetes.shape
# Out:
# (768, 9)

# %%
diabetes.query('Glucose>190')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8              2      197             70             45      543  30.5
# 22             7      196             90              0        0  39.8
# 185            7      194             68             28        0  35.9
# 206            8      196             76             29      280  37.5
# 228            4      197             70             39      744  36.7
# 258            1      193             50             16      375  25.9
# 260            3      191             68             15      130  30.9
# 319            6      194             78              0        0  23.5
# 359            1      196             76             36      249  36.5
# 399            3      193             70             31        0  34.9
# 408            8      197             74              0        0  25.9
# 489            8      194             80              0        0  26.1
# ...

# %%
diabetes['Glucose']
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64

# %%
diabetes[ ['Glucose'] ]
# Out:
#      Glucose
# 0        148
# 1         85
# 2        183
# 3         89
# 4        137
# ..       ...
# 763      101
# 764      122
# 765      121
# 766      126
# 767       93
#
# [768 rows x 1 columns]
